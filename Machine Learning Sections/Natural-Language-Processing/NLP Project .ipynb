# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___

# %% [markdown]
# # Natural Language Processing Project
#
# Welcome to the NLP Project for this section of the course. In this NLP project you will be attempting to classify Yelp Reviews into 1 star or 5 star categories based off the text content in the reviews. This will be a simpler procedure than the lecture, since we will utilize the pipeline methods for more complex tasks.
#
# We will use the [Yelp Review Data Set from Kaggle](https://www.kaggle.com/c/yelp-recsys-2013).
#
# Each observation in this dataset is a review of a particular business by a particular user.
#
# The "stars" column is the number of stars (1 through 5) assigned by the reviewer to the business. (Higher stars is better.) In other words, it is the rating of the business by the person who wrote the review.
#
# The "cool" column is the number of "cool" votes this review received from other Yelp users.
#
# All reviews start with 0 "cool" votes, and there is no limit to how many "cool" votes a review can receive. In other words, it is a rating of the review itself, not a rating of the business.
#
# The "useful" and "funny" columns are similar to the "cool" column.
#
# Let's get started! Just follow the directions below!

# %% [markdown]
# ## Imports
#  **Import the usual suspects. :) **

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## The Data
#
# **Read the yelp.csv file and set it as a dataframe called yelp.**

# %%
yelp = pd.read_csv('yelp.csv')

# %% [markdown]
# ** Check the head, info , and describe methods on yelp.**

# %%
yelp.head()
# Out:
#               business_id        date               review_id  stars  \
# 0  9yKzy9PApeiPPOUJEtnvkg  2011-01-26  fWKvX83p0-ka4JS3dc6E5A      5
# 1  ZRJwVLyzEJq1VAihDhYiow  2011-07-27  IjZ33sJrzXqU-0X6U8NwyA      5
# 2  6oRAC4uyJCsJl1X0WZpVSA  2012-06-14  IESLBzqUCLdSzSqm0eCSxQ      4
# 3  _1QQZuf4zZOyFCvXc0o6Vg  2010-05-27  G-WvGaISbqqaMHlNnByodA      5
# 4  6ozycU1RpktNG2-1BroVtw  2012-01-05  1uJFq2r5QfJG_6ExMRCaGw      5
#
#                                                 text    type  \
# 0  My wife took me here on my birthday for breakf...  review
# 1  I have no idea why some people give bad review...  review
# 2  love the gyro plate. Rice is so good and I als...  review
# 3  Rosie, Dakota, and I LOVE Chaparral Dog Park!!...  review
# 4  General Manager Scott Petello is a good egg!!!...  review
#
#                   user_id  cool  useful  funny
# 0  rLtl8ZkDX5vH5nAx9C3q5Q     2       5      0
# 1  0a2KyEL0d3Yb1V6aivbIuQ     0       0      0
# 2  0hT2KtfLiobPvh6cDC8JQg     0       1      0
# 3  uZetl9T0NcROGOyFfughhg     1       2      0
# 4  vYmM4KTsC8ZfQBg-j5MWkw     0       0      0

# %%
# Out:
#               business_id        date               review_id  stars  \
# 0  9yKzy9PApeiPPOUJEtnvkg  2011-01-26  fWKvX83p0-ka4JS3dc6E5A      5
# 1  ZRJwVLyzEJq1VAihDhYiow  2011-07-27  IjZ33sJrzXqU-0X6U8NwyA      5
# 2  6oRAC4uyJCsJl1X0WZpVSA  2012-06-14  IESLBzqUCLdSzSqm0eCSxQ      4
# 3  _1QQZuf4zZOyFCvXc0o6Vg  2010-05-27  G-WvGaISbqqaMHlNnByodA      5
# 4  6ozycU1RpktNG2-1BroVtw  2012-01-05  1uJFq2r5QfJG_6ExMRCaGw      5
#
#                                                 text    type  \
# 0  My wife took me here on my birthday for breakf...  review
# 1  I have no idea why some people give bad review...  review
# 2  love the gyro plate. Rice is so good and I als...  review
# 3  Rosie, Dakota, and I LOVE Chaparral Dog Park!!...  review
# 4  General Manager Scott Petello is a good egg!!!...  review
#
#                   user_id  cool  useful  funny
# 0  rLtl8ZkDX5vH5nAx9C3q5Q     2       5      0
# 1  0a2KyEL0d3Yb1V6aivbIuQ     0       0      0
# 2  0hT2KtfLiobPvh6cDC8JQg     0       1      0
# 3  uZetl9T0NcROGOyFfughhg     1       2      0
# 4  vYmM4KTsC8ZfQBg-j5MWkw     0       0      0

# %%
yelp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
# business_id    10000 non-null object
# date           10000 non-null object
# review_id      10000 non-null object
# stars          10000 non-null int64
# text           10000 non-null object
# type           10000 non-null object
# user_id        10000 non-null object
# cool           10000 non-null int64
# useful         10000 non-null int64
# funny          10000 non-null int64
# dtypes: int64(4), object(6)
# memory usage: 781.3+ KB

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
# business_id    10000 non-null object
# date           10000 non-null object
# review_id      10000 non-null object
# stars          10000 non-null int64
# text           10000 non-null object
# type           10000 non-null object
# user_id        10000 non-null object
# cool           10000 non-null int64
# useful         10000 non-null int64
# funny          10000 non-null int64
# dtypes: int64(4), object(6)
# memory usage: 781.3+ KB

# %%
yelp.describe()
# Out:
#               stars          cool        useful         funny
# count  10000.000000  10000.000000  10000.000000  10000.000000
# mean       3.777500      0.876800      1.409300      0.701300
# std        1.214636      2.067861      2.336647      1.907942
# min        1.000000      0.000000      0.000000      0.000000
# 25%        3.000000      0.000000      0.000000      0.000000
# 50%        4.000000      0.000000      1.000000      0.000000
# 75%        5.000000      1.000000      2.000000      1.000000
# max        5.000000     77.000000     76.000000     57.000000

# %%
# Out:
#               stars          cool        useful         funny
# count  10000.000000  10000.000000  10000.000000  10000.000000
# mean       3.777500      0.876800      1.409300      0.701300
# std        1.214636      2.067861      2.336647      1.907942
# min        1.000000      0.000000      0.000000      0.000000
# 25%        3.000000      0.000000      0.000000      0.000000
# 50%        4.000000      0.000000      1.000000      0.000000
# 75%        5.000000      1.000000      2.000000      1.000000
# max        5.000000     77.000000     76.000000     57.000000

# %% [markdown]
# **Create a new column called "text length" which is the number of words in the text column.**

# %%
yelp['text length'] = yelp['text'].apply(len)

# %%
yelp.head()
# Out:
#               business_id        date               review_id  stars  \
# 0  9yKzy9PApeiPPOUJEtnvkg  2011-01-26  fWKvX83p0-ka4JS3dc6E5A      5
# 1  ZRJwVLyzEJq1VAihDhYiow  2011-07-27  IjZ33sJrzXqU-0X6U8NwyA      5
# 2  6oRAC4uyJCsJl1X0WZpVSA  2012-06-14  IESLBzqUCLdSzSqm0eCSxQ      4
# 3  _1QQZuf4zZOyFCvXc0o6Vg  2010-05-27  G-WvGaISbqqaMHlNnByodA      5
# 4  6ozycU1RpktNG2-1BroVtw  2012-01-05  1uJFq2r5QfJG_6ExMRCaGw      5
#
#                                                 text    type  \
# 0  My wife took me here on my birthday for breakf...  review
# 1  I have no idea why some people give bad review...  review
# 2  love the gyro plate. Rice is so good and I als...  review
# 3  Rosie, Dakota, and I LOVE Chaparral Dog Park!!...  review
# 4  General Manager Scott Petello is a good egg!!!...  review
#
#                   user_id  cool  useful  funny  text length
# 0  rLtl8ZkDX5vH5nAx9C3q5Q     2       5      0          889
# 1  0a2KyEL0d3Yb1V6aivbIuQ     0       0      0         1345
# 2  0hT2KtfLiobPvh6cDC8JQg     0       1      0           76
# 3  uZetl9T0NcROGOyFfughhg     1       2      0          419
# 4  vYmM4KTsC8ZfQBg-j5MWkw     0       0      0          469

# %% [markdown]
# # EDA
#
# Let's explore the data
#
# ## Imports
#
# **Import the data visualization libraries if you haven't done so already.**

# %%
g = sns.FacetGrid(data=yelp, col='stars', sharey=True)
g = g.map(plt.hist, 'text length', bins=10)

# %% [markdown]
# **Use FacetGrid from the seaborn library to create a grid of 5 histograms of text length based off of the star ratings. Reference the seaborn documentation for hints on this**

# %% [markdown]
# **Create a boxplot of text length for each star category.**

# %%
sns.boxplot(x='stars', y='text length', data=yelp, palette='rainbow')

# %% [markdown]
# **Create a countplot of the number of occurrences for each type of star rating.**

# %%
sns.countplot(x='stars', data=yelp, palette='rainbow')

# %% [markdown]
# ** Use groupby to get the mean values of the numerical columns, you should be able to create this dataframe with the operation:**

# %%
yelp.groupby('stars').mean()
# Out:
#            cool    useful     funny  text length
# stars
# 1      0.576769  1.604806  1.056075   826.515354
# 2      0.719525  1.563107  0.875944   842.256742
# 3      0.788501  1.306639  0.694730   758.498289
# 4      0.954623  1.395916  0.670448   712.923142
# 5      0.944261  1.381780  0.608631   624.999101

# %%
# Out:
#            cool    useful     funny  text length
# stars
# 1      0.576769  1.604806  1.056075   826.515354
# 2      0.719525  1.563107  0.875944   842.256742
# 3      0.788501  1.306639  0.694730   758.498289
# 4      0.954623  1.395916  0.670448   712.923142
# 5      0.944261  1.381780  0.608631   624.999101

# %% [markdown]
# **Use the corr() method on that groupby dataframe to produce this dataframe:**

# %%
yelp.groupby('stars').mean().corr()
# Out:
#                  cool    useful     funny  text length
# cool         1.000000 -0.743329 -0.944939    -0.857664
# useful      -0.743329  1.000000  0.894506     0.699881
# funny       -0.944939  0.894506  1.000000     0.843461
# text length -0.857664  0.699881  0.843461     1.000000

# %%
# Out:
#                  cool    useful     funny  text length
# cool         1.000000 -0.743329 -0.944939    -0.857664
# useful      -0.743329  1.000000  0.894506     0.699881
# funny       -0.944939  0.894506  1.000000     0.843461
# text length -0.857664  0.699881  0.843461     1.000000

# %% [markdown]
# **Then use seaborn to create a heatmap based off that .corr() dataframe:**

# %%
sns.heatmap(yelp.groupby('stars').mean().corr(), cmap='coolwarm', annot=True)

# %% [markdown]
# ## NLP Classification Task
#
# Let's move on to the actual task. To make things a little easier, go ahead and only grab reviews that were either 1 star or 5 stars.
#
# **Create a dataframe called yelp_class that contains the columns of yelp dataframe but for only the 1 or 5 star reviews.**

# %%
yelp_class2 = yelp[(yelp['stars'] == 1) | (yelp['stars'] == 5)]

# %%
yelp_class2
# Out:
#                  business_id        date               review_id  stars  \
# 0     9yKzy9PApeiPPOUJEtnvkg  2011-01-26  fWKvX83p0-ka4JS3dc6E5A      5
# 9990  R8VwdLyvsp9iybNqRvm94g  2011-10-03  pcEeHdAJPoFNF23es0kKWg      5
# 9991  WJ5mq4EiWYAA4Vif0xDfdg  2011-12-05  EuHX-39FR7tyyG1ElvN1Jw      5
# 9992  f96lWMIAUhYIYy9gOktivQ  2009-03-10  YF17z7HWlMj6aezZc-pVEw      5
# 9994  L3BSpFvxcNf3T_teitgt6A  2012-03-19  0nxb1gIGFgk3WbC5zwhKZg      5
# 9999  pF7uRzygyZsltbmVpjIyvw  2010-10-16  vWSmOhg2ID1MNZHaWapGbA      5
#
#                                                    text    type  \
# 0     My wife took me here on my birthday for breakf...  review
# 1     I have no idea why some people give bad review...  review
# 3     Rosie, Dakota, and I LOVE Chaparral Dog Park!!...  review
# 4     General Manager Scott Petello is a good egg!!!...  review
# 6     Drop what you're doing and drive here. After I...  review
# 9     Nobuo shows his unique talents with everything...  review
# 10    The oldish man who owns the store is as sweet ...  review
# 11    Wonderful Vietnamese sandwich shoppe. Their ba...  review
# 12    They have a limited time thing going on right ...  review
# 17    okay this is the best place EVER! i grew up sh...  review
# 21    This place shouldn't even be reviewed - becaus...  review
# 22    first time my friend and I went there... it wa...  review
# 23    U can go there n check the car out. If u wanna...  review
# 24    I love this place! I have been coming here for...  review
# 26    I love love LOVE this place. My boss (who is i...  review
# 30    Disclaimer: Like many of you, I am a sucker fo...  review
# 31    Disgusting!  Had a Groupon so my daughter and ...  review
# 32    Never having dealt with a Discount Tire in Pho...  review
# 35    I've eaten here many times, but none as bad as...  review
# 46    (Un)fortunately for me, lux is close to my hou...  review
# 51    Fred M. pretty much said what I would say, so ...  review
# 54    Alright, I have been away from Yelp for quite ...  review
# 59    This restaurant is incredible, and has the bes...  review
# 61    I have always been a fan of Burlington's deals...  review
# 64    Another night meeting friends here.  I have to...  review
# 65    Not busy at all but took nearly 45 min to get ...  review
# 66    This an incredible church that embraces the pr...  review
# 67    This is our favorite breakfast place. The food...  review
# 69    I had looked at several invitation websites al...  review
# 71    Yikes, reading other reviews I realize my bad ...  review
# ...                                                 ...     ...
# 9941  I have a fond place in my heart for this estab...  review
# 9942  Cork is an enigma.\n\nWhat makes it enigmatic ...  review
# 9943  Went to Yogurt Kingdom for the first time toni...  review
# 9945  I find it hilarious that someone would referen...  review
# 9947                                    LOVE Five Guys!  review
# 9951  This is a great Mexican food restaurant. I eat...  review
# 9953  "Hipster,Trendy" ????-I think NOT !!!! Very di...  review
# 9956  "So Jimmy, tell the class what you saw at Swee...  review
# 9957  Standard Mexican fare - but quite delicious.  ...  review
# 9959  My profile says....\n\nMy Last Meal On Earth: ...  review
# 9965  Treats: We tried the cookies (chocolate chip a...  review
# 9966  I first joined 24 hr fitness about a year ago,...  review
# 9969  Leah, the trainer, at Dog House Training Acade...  review
# 9970  This place is super cute lunch joint.  I had t...  review
# 9971  The staff is great, the food is great, even th...  review
# 9973  Wow!  Went on a Sunday around 11am - busy but ...  review
# 9975  When I lived in Phoenix, I was a regular at Fe...  review
# 9977  Why did I wait so long to try this neighborhoo...  review
# 9978  This is the place for a fabulos breakfast!! I ...  review
# 9979  Highly recommend. This is my second time here ...  review
# 9980  5 stars for the great $5 happy hour specials. ...  review
# 9981  We brought the entire family to Giuseppe's las...  review
# 9984  Went last night to Whore Foods to get basics t...  review
# 9987  The food is delicious.  The service:  discrimi...  review
# 9989  Great food and service! Country food at its best!  review
# 9990  Yes I do rock the hipster joints.  I dig this ...  review
# 9991  Only 4 stars? \n\n(A few notes: The folks that...  review
# 9992  I'm not normally one to jump at reviewing a ch...  review
# 9994  Let's see...what is there NOT to like about Su...  review
# 9999  4-5 locations.. all 4.5 star average.. I think...  review
#
#                      user_id  cool  useful  funny  text length
# 0     rLtl8ZkDX5vH5nAx9C3q5Q     2       5      0          889
# 1     0a2KyEL0d3Yb1V6aivbIuQ     0       0      0         1345
# 3     uZetl9T0NcROGOyFfughhg     1       2      0          419
# 4     vYmM4KTsC8ZfQBg-j5MWkw     0       0      0          469
# 6     wFweIWhv2fREZV_dYkz_1g     7       7      4         1565
# 9     sUNkXg8-KFtCMQDV6zRzQg     0       1      0          186
# 10    -OMlS6yWkYjVldNhC31wYg     1       3      1          298
# 11    C1rHp3dmepNea7XiouwB6Q     1       1      0          321
# 12    UPtysDF6cUDUxq2KY-6Dcg     1       2      0          433
# 17    u1KWcbPMvXFEEYkZZ0Yktg     0       0      0          363
# 21    YN3ZLOdg8kpnfbVcIhuEZA     1       1      2          104
# 22    6lg55RIP23VhjYEBXJ8Njw     0       0      0          148
# 23    zRlQEDYd_HKp0VS3hnAffA     0       1      1          594
# 24    13xj6FSvYO0rZVRv5XZp4w     0       1      0          294
# 26    fpItLlgimq0nRltWOkuJJw     0       0      0          921
# 30    bCKjygWJZOQHCOzootbvow     0       2      0          801
# 31    8AMn6644NmBf96xGO3w6OA     0       1      0          361
# 32    HLbhD2OyiMCUDRR4c1iXaw     0       0      0         1734
# 35    iwUN95LIaEr75TZE_JC6bg     0       4      3         1198
# 46    IUWjTmXc3wLVaMHz33inaA     2       1      1          194
# 51    aqqbh1NZoFk48kp0eqSLdg     3       2      1          197
# 54    yy1SbjeyWiAhWfSr5d0new     2       3      3         1139
# 59    U3uT-Phb8iL2iuZpAROZlg     0       0      0          757
# 61    EPROVap0M19Y6_4uf3eCmQ     0       0      0          569
# 64    MjLAe48XNfYlTeFYca5gMw     0       1      2          498
# 65    rWN1pg3mCF2btJWtG6JmJA     0       1      0          304
# 66    0jJhjgr3wPin-8vYnPab6A     0       0      0          344
# 67    -yg_AMAU2HNh48zcuQ13mw     0       1      0          253
# 69    xP3o3-r0KRUnZqBSdIGJjw     0       0      0          506
# 71    5je-Jg8tq5BWxJtDBmTK2Q     0       6      1          877
# ...                      ...   ...     ...    ...          ...
# 9941  PShy2RYNadDUhJf4ErOJ7w     1       1      3          606
# 9942  l81ILmOhky5bG7o4r3rkhQ     8      12      6         1194
# 9943  haYHbLXLX2cmHq1wQAEtfg     0       0      0          943
# 9945  9g_ARKx0eJmNH8oO1TR9rQ     0       0      1         2619
# 9947  FYdLG8vxUfhqd6v-QQHRkw     0       0      0           15
# 9951  fi5y6-daDzTIQ7wOKaR7xg     0       0      0          309
# 9953  JEQ6el2-tLtKJU6k_SpE-w     0       2      0          296
# 9956  P2kVk4cIWyK4e4h14RhK-Q    14      15     16          786
# 9957  TnTkd3MKoIOKqrsPDzhiog     0       0      0          118
# 9959  EDN_wou8EEkuaj5Pd83cQA     2       2      1          754
# 9965  2lvfBteL5ny4CBjNIk9Mwg     0       0      0          648
# 9966  iPnpD62l5LUL7WXaI3SJFA     0       0      1          962
# 9969  RKxsZo6XkRU-0y1JgqqsBA     1       1      0          938
# 9970  mtoKqaQjGPWEc5YZbrYV9w     0       0      0          432
# 9971  uBAMd01ZtGXaHrRD6THNzg     1       2      1          318
# 9973  yRYNx24kUDRRBfJu1Rcojg     0       0      0          353
# 9975  TLj3XaclA7V4ldJ5yNP-9Q     1       1      0         1015
# 9977  Id-8-NMEKxeXBR44eUdDeA     3       6      3         2918
# 9978  vasHsAZEgLZGJDTlIweUYQ     0       1      0          493
# 9979  bJFdmJJxfXgCYA5DMmyeqQ     2       2      1          244
# 9980  xZvRLPJ1ixhFVomkXSfXAw     6       6      4          393
# 9981  fczQCSmaWF78toLEmb0Zsw    10       9      5          885
# 9984  W7zmm1uzlyUkEqpSG7PlBw     0       1      2         1673
# 9987  toPtsUtYoRB-5-ThrOy2Fg     0       0      0          200
# 9989  fKaO8fR1IAcfvZb6cBrs2w     0       1      0           49
# 9990  b92Y3tyWTQQZ5FLifex62Q     1       1      1          263
# 9991  hTau-iNZFwoNsPCaiIUTEA     1       1      0          908
# 9992  W_QXYA7A0IhMrvbckz7eVg     2       3      2         1326
# 9994  OzOZv-Knlw3oz9K5Kh5S6A     1       2      1         1968
# 9999  KSBFytcdjPKZgXKQnYQdkA     0       0      0          461
#
# [4086 rows x 11 columns]

# %%
yelp_class2.shape
# Out:
# (4086, 11)

# %%
yelp_class.shape
# Out:
# (10000, 11)

# %%
def starcheck (row):
    if row['stars'] == 1 or row['stars'] == 5:
        return row

# %%
yelp_class = yelp.apply(starcheck, axis=1)

# %%
yelp_class = yelp_class.dropna()

# %%
yelp_class
# Out:
#                  business_id        date               review_id  stars  \
# 0     9yKzy9PApeiPPOUJEtnvkg  2011-01-26  fWKvX83p0-ka4JS3dc6E5A    5.0
# 1     ZRJwVLyzEJq1VAihDhYiow  2011-07-27  IjZ33sJrzXqU-0X6U8NwyA    5.0
# 3     _1QQZuf4zZOyFCvXc0o6Vg  2010-05-27  G-WvGaISbqqaMHlNnByodA    5.0
# 4     6ozycU1RpktNG2-1BroVtw  2012-01-05  1uJFq2r5QfJG_6ExMRCaGw    5.0
# 6     zp713qNhx8d9KCJJnrw1xA  2010-02-12  riFQ3vxNpP4rWLk_CSri2A    5.0
# 9     nMHhuYan8e3cONo3PornJA  2010-08-11  jJAIXA46pU1swYyRCdfXtQ    5.0
# 10    AsSCv0q_BWqIe3mX2JqsOQ  2010-06-16  E11jzpKz9Kw5K7fuARWfRw    5.0
# 11    e9nN4XxjdHj4qtKCOPq_vg  2011-10-21  3rPt0LxF7rgmEUrznoH22w    5.0
# 12    h53YuCiIDfEFSJCQpk8v1g  2010-01-11  cGnKNX3I9rthE0-TH24-qA    5.0
# 3     Rosie, Dakota, and I LOVE Chaparral Dog Park!!...  review
# 4     General Manager Scott Petello is a good egg!!!...  review
# 6     Drop what you're doing and drive here. After I...  review
# 9     Nobuo shows his unique talents with everything...  review
# 10    The oldish man who owns the store is as sweet ...  review
# 11    Wonderful Vietnamese sandwich shoppe. Their ba...  review
# 12    They have a limited time thing going on right ...  review
# 17    okay this is the best place EVER! i grew up sh...  review
# 21    This place shouldn't even be reviewed - becaus...  review
# 22    first time my friend and I went there... it wa...  review
# 23    U can go there n check the car out. If u wanna...  review
# 24    I love this place! I have been coming here for...  review
# 26    I love love LOVE this place. My boss (who is i...  review
# 30    Disclaimer: Like many of you, I am a sucker fo...  review
# 31    Disgusting!  Had a Groupon so my daughter and ...  review
# 32    Never having dealt with a Discount Tire in Pho...  review
# 35    I've eaten here many times, but none as bad as...  review
# 46    (Un)fortunately for me, lux is close to my hou...  review
# 51    Fred M. pretty much said what I would say, so ...  review
# 54    Alright, I have been away from Yelp for quite ...  review
# 59    This restaurant is incredible, and has the bes...  review
# 61    I have always been a fan of Burlington's deals...  review
# 64    Another night meeting friends here.  I have to...  review
# 65    Not busy at all but took nearly 45 min to get ...  review
# 66    This an incredible church that embraces the pr...  review
# 67    This is our favorite breakfast place. The food...  review
# 69    I had looked at several invitation websites al...  review
# 71    Yikes, reading other reviews I realize my bad ...  review
# ...                                                 ...     ...
# 9941  I have a fond place in my heart for this estab...  review
# 9942  Cork is an enigma.\n\nWhat makes it enigmatic ...  review
# 9943  Went to Yogurt Kingdom for the first time toni...  review
# 9945  I find it hilarious that someone would referen...  review
# 9947                                    LOVE Five Guys!  review
# 9951  This is a great Mexican food restaurant. I eat...  review
# 9953  "Hipster,Trendy" ????-I think NOT !!!! Very di...  review
# 9956  "So Jimmy, tell the class what you saw at Swee...  review
# 9957  Standard Mexican fare - but quite delicious.  ...  review
# 9959  My profile says....\n\nMy Last Meal On Earth: ...  review
# 9965  Treats: We tried the cookies (chocolate chip a...  review
# 9966  I first joined 24 hr fitness about a year ago,...  review
# 9969  Leah, the trainer, at Dog House Training Acade...  review
# 9970  This place is super cute lunch joint.  I had t...  review
# 9971  The staff is great, the food is great, even th...  review
# 9973  Wow!  Went on a Sunday around 11am - busy but ...  review
# 9975  When I lived in Phoenix, I was a regular at Fe...  review
# 9977  Why did I wait so long to try this neighborhoo...  review
# 9978  This is the place for a fabulos breakfast!! I ...  review
# 9979  Highly recommend. This is my second time here ...  review
# 9980  5 stars for the great $5 happy hour specials. ...  review
# 9981  We brought the entire family to Giuseppe's las...  review
# 9984  Went last night to Whore Foods to get basics t...  review
# 9987  The food is delicious.  The service:  discrimi...  review
# 9989  Great food and service! Country food at its best!  review
# 9990  Yes I do rock the hipster joints.  I dig this ...  review
# 9991  Only 4 stars? \n\n(A few notes: The folks that...  review
# 9992  I'm not normally one to jump at reviewing a ch...  review
# 9994  Let's see...what is there NOT to like about Su...  review
# 9999  4-5 locations.. all 4.5 star average.. I think...  review
#
#                      user_id  cool  useful  funny  text length
# 0     rLtl8ZkDX5vH5nAx9C3q5Q   2.0     5.0    0.0        889.0
# 9956  P2kVk4cIWyK4e4h14RhK-Q  14.0    15.0   16.0        786.0
# 9957  TnTkd3MKoIOKqrsPDzhiog   0.0     0.0    0.0        118.0
# 9959  EDN_wou8EEkuaj5Pd83cQA   2.0     2.0    1.0        754.0
# 9965  2lvfBteL5ny4CBjNIk9Mwg   0.0     0.0    0.0        648.0
# 9966  iPnpD62l5LUL7WXaI3SJFA   0.0     0.0    1.0        962.0
# 9969  RKxsZo6XkRU-0y1JgqqsBA   1.0     1.0    0.0        938.0
# 9970  mtoKqaQjGPWEc5YZbrYV9w   0.0     0.0    0.0        432.0
# 9971  uBAMd01ZtGXaHrRD6THNzg   1.0     2.0    1.0        318.0
# 9973  yRYNx24kUDRRBfJu1Rcojg   0.0     0.0    0.0        353.0
# 9975  TLj3XaclA7V4ldJ5yNP-9Q   1.0     1.0    0.0       1015.0
# 9977  Id-8-NMEKxeXBR44eUdDeA   3.0     6.0    3.0       2918.0
# 9978  vasHsAZEgLZGJDTlIweUYQ   0.0     1.0    0.0        493.0
# 9979  bJFdmJJxfXgCYA5DMmyeqQ   2.0     2.0    1.0        244.0
# 9980  xZvRLPJ1ixhFVomkXSfXAw   6.0     6.0    4.0        393.0
# 9981  fczQCSmaWF78toLEmb0Zsw  10.0     9.0    5.0        885.0
# 9984  W7zmm1uzlyUkEqpSG7PlBw   0.0     1.0    2.0       1673.0
# 9987  toPtsUtYoRB-5-ThrOy2Fg   0.0     0.0    0.0        200.0
# 9989  fKaO8fR1IAcfvZb6cBrs2w   0.0     1.0    0.0         49.0
# 9990  b92Y3tyWTQQZ5FLifex62Q   1.0     1.0    1.0        263.0
# 9991  hTau-iNZFwoNsPCaiIUTEA   1.0     1.0    0.0        908.0
# 9992  W_QXYA7A0IhMrvbckz7eVg   2.0     3.0    2.0       1326.0
# 9994  OzOZv-Knlw3oz9K5Kh5S6A   1.0     2.0    1.0       1968.0
# 9999  KSBFytcdjPKZgXKQnYQdkA   0.0     0.0    0.0        461.0
#
# [4086 rows x 11 columns]

# %%
yelp_class = yelp_class.reset_index(drop=True)

# %%
yelp_class
# Out:
#                  business_id        date               review_id  stars  \
# 0     9yKzy9PApeiPPOUJEtnvkg  2011-01-26  fWKvX83p0-ka4JS3dc6E5A    5.0
# 1     ZRJwVLyzEJq1VAihDhYiow  2011-07-27  IjZ33sJrzXqU-0X6U8NwyA    5.0
# 2     _1QQZuf4zZOyFCvXc0o6Vg  2010-05-27  G-WvGaISbqqaMHlNnByodA    5.0
# 3     6ozycU1RpktNG2-1BroVtw  2012-01-05  1uJFq2r5QfJG_6ExMRCaGw    5.0
# 4     zp713qNhx8d9KCJJnrw1xA  2010-02-12  riFQ3vxNpP4rWLk_CSri2A    5.0
# 5     nMHhuYan8e3cONo3PornJA  2010-08-11  jJAIXA46pU1swYyRCdfXtQ    5.0
# 6     AsSCv0q_BWqIe3mX2JqsOQ  2010-06-16  E11jzpKz9Kw5K7fuARWfRw    5.0
# 7     e9nN4XxjdHj4qtKCOPq_vg  2011-10-21  3rPt0LxF7rgmEUrznoH22w    5.0
# 8     h53YuCiIDfEFSJCQpk8v1g  2010-01-11  cGnKNX3I9rthE0-TH24-qA    5.0
# 4063  P2kVk4cIWyK4e4h14RhK-Q  14.0    15.0   16.0        786.0
# 4064  TnTkd3MKoIOKqrsPDzhiog   0.0     0.0    0.0        118.0
# 4065  EDN_wou8EEkuaj5Pd83cQA   2.0     2.0    1.0        754.0
# 4066  2lvfBteL5ny4CBjNIk9Mwg   0.0     0.0    0.0        648.0
# 4067  iPnpD62l5LUL7WXaI3SJFA   0.0     0.0    1.0        962.0
# 4068  RKxsZo6XkRU-0y1JgqqsBA   1.0     1.0    0.0        938.0
# 4069  mtoKqaQjGPWEc5YZbrYV9w   0.0     0.0    0.0        432.0
# 4070  uBAMd01ZtGXaHrRD6THNzg   1.0     2.0    1.0        318.0
# 4071  yRYNx24kUDRRBfJu1Rcojg   0.0     0.0    0.0        353.0
# 4072  TLj3XaclA7V4ldJ5yNP-9Q   1.0     1.0    0.0       1015.0
# 4073  Id-8-NMEKxeXBR44eUdDeA   3.0     6.0    3.0       2918.0
# 4074  vasHsAZEgLZGJDTlIweUYQ   0.0     1.0    0.0        493.0
# 4075  bJFdmJJxfXgCYA5DMmyeqQ   2.0     2.0    1.0        244.0
# 4076  xZvRLPJ1ixhFVomkXSfXAw   6.0     6.0    4.0        393.0
# 4077  fczQCSmaWF78toLEmb0Zsw  10.0     9.0    5.0        885.0
# 4078  W7zmm1uzlyUkEqpSG7PlBw   0.0     1.0    2.0       1673.0
# 4079  toPtsUtYoRB-5-ThrOy2Fg   0.0     0.0    0.0        200.0
# 4080  fKaO8fR1IAcfvZb6cBrs2w   0.0     1.0    0.0         49.0
# 4081  b92Y3tyWTQQZ5FLifex62Q   1.0     1.0    1.0        263.0
# 4082  hTau-iNZFwoNsPCaiIUTEA   1.0     1.0    0.0        908.0
# 4083  W_QXYA7A0IhMrvbckz7eVg   2.0     3.0    2.0       1326.0
# 4084  OzOZv-Knlw3oz9K5Kh5S6A   1.0     2.0    1.0       1968.0
# 4085  KSBFytcdjPKZgXKQnYQdkA   0.0     0.0    0.0        461.0
#
# [4086 rows x 11 columns]

# %% [markdown]
# ** Create two objects X and y. X will be the 'text' column of yelp_class and y will be the 'stars' column of yelp_class. (Your features and target/labels)**

# %%
X = yelp_class['text']
y = yelp_class['stars']

# %% [markdown]
# **Import CountVectorizer and create a CountVectorizer object.**

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# ** Use the fit_transform method on the CountVectorizer object and pass in X (the 'text' column). Save this result by overwriting X.**

# %%
vect = CountVectorizer()

# %%
X = vect.fit_transform(X)

# %% [markdown]
# ## Train Test Split
#
# Let's split our data into training and testing data.
#
# ** Use train_test_split to split up the data into X_train, X_test, y_train, y_test. Use test_size=0.3 and random_state=101 **

# %%
from sklearn.cross_validation import train_test_split
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %% [markdown]
# ## Training a Model
#
# Time to train a model!
#
# ** Import MultinomialNB and create an instance of the estimator and call is nb **

# %%
from sklearn.naive_bayes import MultinomialNB
nb = MultinomialNB()

# %% [markdown]
# **Now fit nb using the training data.**

# %%
nb.fit(X_train, y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %% [markdown]
# ## Predictions and Evaluations
#
# Time to see how our model did!
#
# **Use the predict method off of nb to predict labels from X_test.**

# %%
pred = nb.predict(X_test)

# %% [markdown]
# ** Create a confusion matrix and classification report using these predictions and y_test **

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, pred))
print(classification_report(y_test, pred))
# Out:
# [[159  69]
#  [ 22 976]]
#              precision    recall  f1-score   support
#
#         1.0       0.88      0.70      0.78       228
#         5.0       0.93      0.98      0.96       998
#
# avg / total       0.92      0.93      0.92      1226

# %%
# Out:
# [[159  69]
#  [ 22 976]]
#
#
#              precision    recall  f1-score   support
#
#           1       0.88      0.70      0.78       228
#           5       0.93      0.98      0.96       998
#
# avg / total       0.92      0.93      0.92      1226

# %% [markdown]
# **Great! Let's see what happens if we try to include TF-IDF to this process using a pipeline.**

# %% [markdown]
# # Using Text Processing
#
# ** Import TfidfTransformer from sklearn. **

# %%
from sklearn.feature_extraction.text import TfidfTransformer

# %% [markdown]
# ** Import Pipeline from sklearn. **

# %%
from sklearn.pipeline import Pipeline

# %% [markdown]
# ** Now create a pipeline with the following steps:CountVectorizer(), TfidfTransformer(),MultinomialNB()**

# %%
pipe = Pipeline([
    ('bow', CountVectorizer()),
    ('classifier', MultinomialNB())
])

# %% [markdown]
# ## Using the Pipeline
#
# **Time to use the pipeline! Remember this pipeline has all your pre-process steps in it already, meaning we'll need to re-split the original data (Remember that we overwrote X as the CountVectorized version. What we need is just the text**

# %% [markdown]
# ### Train Test Split
#
# **Redo the train test split on the yelp_class object.**

# %%
X_train, X_test, y_train, y_test = train_test_split(yelp_class['text'], yelp_class['stars'], test_size=0.3, random_state=101)

# %% [markdown]
# **Now fit the pipeline to the training data. Remember you can't use the same training data as last time because that data has already been vectorized. We need to pass in just the text and labels**

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('bow', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)), ('classifier', MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))])

# %%
# Out:
# Pipeline(steps=[('bow', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_...f=False, use_idf=True)), ('classifier', MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))])

# %% [markdown]
# ### Predictions and Evaluation
#
# ** Now use the pipeline to predict from the X_test and create a classification report and confusion matrix. You should notice strange results.**

# %%
pipe_pred = pipe.predict(X_test)

# %%
print(confusion_matrix(y_test, pipe_pred))
print(classification_report(y_test, pipe_pred))
# Out:
# [[155  73]
#  [ 15 983]]
#              precision    recall  f1-score   support
#
#         1.0       0.91      0.68      0.78       228
#         5.0       0.93      0.98      0.96       998
#
# avg / total       0.93      0.93      0.92      1226

# %%
# Out:
# [[  0 228]
#  [  0 998]]
#              precision    recall  f1-score   support
#
#           1       0.00      0.00      0.00       228
#           5       0.81      1.00      0.90       998
#
# avg / total       0.66      0.81      0.73      1226
# /Users/marci/anaconda/lib/python3.5/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# Looks like Tf-Idf actually made things worse! That is it for this project. But there is still a lot more you can play with:
#
# **Some other things to try....**
# Try going back and playing around with the pipeline steps and seeing if creating a custom analyzer like we did in the lecture helps (note: it probably won't). Or recreate the pipeline with just the CountVectorizer() and NaiveBayes. Does changing the ML model at the end to another classifier help at all?

# %% [markdown]
# # Great Job!
